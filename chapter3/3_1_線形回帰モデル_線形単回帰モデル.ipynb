# %% [markdown]
# <a href="https://colab.research.google.com/github/sammy-suyama/PythonBayesianMLBook/blob/main/chapter3/3_1_%E7%B7%9A%E5%BD%A2%E5%9B%9E%E5%B8%B0%E3%83%A2%E3%83%87%E3%83%AB_%E7%B7%9A%E5%BD%A2%E5%8D%98%E5%9B%9E%E5%B8%B0%E3%83%A2%E3%83%87%E3%83%AB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title install packages
# !pip install watermark
#!pip install pymc3==3.11.4
# !pip install pymc3
# Out:
# Requirement already satisfied: watermark in /Users/sugiurahajime/programming/PythonBayesianMLBook/.venv/lib/python3.9/site-packages (2.3.1)
# Requirement already satisfied: ipython in /Users/sugiurahajime/programming/PythonBayesianMLBook/.venv/lib/python3.9/site-packages (from watermark) (8.4.0)
# Requirement already satisfied: pickleshare in /Users/sugiurahajime/programming/PythonBayesianMLBook/.venv/lib/python3.9/site-packages (from ipython->watermark) (0.7.5)
# Requirement already satisfied: backcall in /Users/sugiurahajime/programming/PythonBayesianMLBook/.venv/lib/python3.9/site-packages (from ipython->watermark) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in /Users/sugiurahajime/programming/PythonBayesianMLBook/.venv/lib/python3.9/site-packages (from ipython->watermark) (60.10.0)
# Requirement already satisfied: pygments>=2.4.0 in /Users/sugiurahajime/programming/PythonBayesianMLBook/.venv/lib/python3.9/site-packages (from ipython->watermark) (2.12.0)
# Requirement already satisfied: matplotlib-inline in /Users/sugiurahajime/programming/PythonBayesianMLBook/.venv/lib/python3.9/site-packages (from ipython->watermark) (0.1.3)
# Requirement already satisfied: decorator in /Users/sugiurahajime/programming/PythonBayesianMLBook/.venv/lib/python3.9/site-packages (from ipython->watermark) (5.1.1)
# Requirement already satisfied: appnope in /Users/sugiurahajime/programming/PythonBayesianMLBook/.venv/lib/python3.9/site-packages (from ipython->watermark) (0.1.3)
# Requirement already satisfied: stack-data in /Users/sugiurahajime/programming/PythonBayesianMLBook/.venv/lib/python3.9/site-packages (from ipython->watermark) (0.2.0)
# Requirement already satisfied: traitlets>=5 in /Users/sugiurahajime/programming/PythonBayesianMLBook/.venv/lib/python3.9/site-packages (from ipython->watermark) (5.2.2.post1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/sugiurahajime/programming/PythonBayesianMLBook/.venv/lib/python3.9/site-packages (from ipython->watermark) (3.0.29)
# Requirement already satisfied: jedi>=0.16 in /Users/sugiurahajime/programming/PythonBayesianMLBook/.venv/lib/python3.9/site-packages (from ipython->watermark) (0.18.1)
# Requirement already satisfied: pexpect>4.3 in /Users/sugiurahajime/programming/PythonBayesianMLBook/.venv/lib/python3.9/site-packages (from ipython->watermark) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/sugiurahajime/programming/PythonBayesianMLBook/.venv/lib/python3.9/site-packages (from jedi>=0.16->ipython->watermark) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/sugiurahajime/programming/PythonBayesianMLBook/.venv/lib/python3.9/site-packages (from pexpect>4.3->ipython->watermark) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/sugiurahajime/programming/PythonBayesianMLBook/.venv/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->watermark) (0.2.5)
# Requirement already satisfied: executing in /Users/sugiurahajime/programming/PythonBayesianMLBook/.venv/lib/python3.9/site-packages (from stack-data->ipython->watermark) (0.8.3)
# Requirement already satisfied: pure-eval in /Users/sugiurahajime/programming/PythonBayesianMLBook/.venv/lib/python3.9/site-packages (from stack-data->ipython->watermark) (0.2.2)
# Requirement already satisfied: asttokens in /Users/sugiurahajime/programming/PythonBayesianMLBook/.venv/lib/python3.9/site-packages (from stack-data->ipython->watermark) (2.0.5)
# Requirement already satisfied: six in /Users/sugiurahajime/programming/PythonBayesianMLBook/.venv/lib/python3.9/site-packages (from asttokens->stack-data->ipython->watermark) (1.16.0)
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the '/Users/sugiurahajime/programming/PythonBayesianMLBook/.venv/bin/python3.9 -m pip install --upgrade pip' command.
# Requirement already satisfied: pymc3 in /Users/sugiurahajime/programming/PythonBayesianMLBook/.venv/lib/python3.9/site-packages (3.11.5)
# Requirement already satisfied: semver>=2.13.0 in /Users/sugiurahajime/programming/PythonBayesianMLBook/.venv/lib/python3.9/site-packages (from pymc3) (2.13.0)
# Requirement already satisfied: theano-pymc==1.1.2 in /Users/sugiurahajime/programming/PythonBayesianMLBook/.venv/lib/python3.9/site-packages (from pymc3) (1.1.2)
# Requirement already satisfied: scipy<1.8.0,>=1.7.3 in /Users/sugiurahajime/programming/PythonBayesianMLBook/.venv/lib/python3.9/site-packages (from pymc3) (1.7.3)
# Requirement already satisfied: cachetools>=4.2.1 in /Users/sugiurahajime/programming/PythonBayesianMLBook/.venv/lib/python3.9/site-packages (from pymc3) (5.2.0)
# Requirement already satisfied: deprecat in /Users/sugiurahajime/programming/PythonBayesianMLBook/.venv/lib/python3.9/site-packages (from pymc3) (2.1.1)
# Requirement already satisfied: typing-extensions>=3.7.4 in /Users/sugiurahajime/programming/PythonBayesianMLBook/.venv/lib/python3.9/site-packages (from pymc3) (4.2.0)
# Requirement already satisfied: numpy<1.22.2,>=1.15.0 in /Users/sugiurahajime/programming/PythonBayesianMLBook/.venv/lib/python3.9/site-packages (from pymc3) (1.22.1)
# Requirement already satisfied: pandas>=0.24.0 in /Users/sugiurahajime/programming/PythonBayesianMLBook/.venv/lib/python3.9/site-packages (from pymc3) (1.4.2)
# Requirement already satisfied: dill in /Users/sugiurahajime/programming/PythonBayesianMLBook/.venv/lib/python3.9/site-packages (from pymc3) (0.3.5.1)
# Requirement already satisfied: arviz>=0.11.0 in /Users/sugiurahajime/programming/PythonBayesianMLBook/.venv/lib/python3.9/site-packages (from pymc3) (0.12.1)
# Requirement already satisfied: fastprogress>=0.2.0 in /Users/sugiurahajime/programming/PythonBayesianMLBook/.venv/lib/python3.9/site-packages (from pymc3) (1.0.2)
# Requirement already satisfied: patsy>=0.5.1 in /Users/sugiurahajime/programming/PythonBayesianMLBook/.venv/lib/python3.9/site-packages (from pymc3) (0.5.2)
# Requirement already satisfied: filelock in /Users/sugiurahajime/programming/PythonBayesianMLBook/.venv/lib/python3.9/site-packages (from theano-pymc==1.1.2->pymc3) (3.7.1)
# Requirement already satisfied: setuptools>=38.4 in /Users/sugiurahajime/programming/PythonBayesianMLBook/.venv/lib/python3.9/site-packages (from arviz>=0.11.0->pymc3) (60.10.0)
# Requirement already satisfied: packaging in /Users/sugiurahajime/programming/PythonBayesianMLBook/.venv/lib/python3.9/site-packages (from arviz>=0.11.0->pymc3) (21.3)
# Requirement already satisfied: netcdf4 in /Users/sugiurahajime/programming/PythonBayesianMLBook/.venv/lib/python3.9/site-packages (from arviz>=0.11.0->pymc3) (1.5.8)
# Requirement already satisfied: xarray>=0.16.1 in /Users/sugiurahajime/programming/PythonBayesianMLBook/.venv/lib/python3.9/site-packages (from arviz>=0.11.0->pymc3) (2022.3.0)
# Requirement already satisfied: matplotlib>=3.0 in /Users/sugiurahajime/programming/PythonBayesianMLBook/.venv/lib/python3.9/site-packages (from arviz>=0.11.0->pymc3) (3.5.2)
# Requirement already satisfied: xarray-einstats>=0.2 in /Users/sugiurahajime/programming/PythonBayesianMLBook/.venv/lib/python3.9/site-packages (from arviz>=0.11.0->pymc3) (0.2.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/sugiurahajime/programming/PythonBayesianMLBook/.venv/lib/python3.9/site-packages (from pandas>=0.24.0->pymc3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/sugiurahajime/programming/PythonBayesianMLBook/.venv/lib/python3.9/site-packages (from pandas>=0.24.0->pymc3) (2022.1)
# Requirement already satisfied: six in /Users/sugiurahajime/programming/PythonBayesianMLBook/.venv/lib/python3.9/site-packages (from patsy>=0.5.1->pymc3) (1.16.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /Users/sugiurahajime/programming/PythonBayesianMLBook/.venv/lib/python3.9/site-packages (from deprecat->pymc3) (1.14.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/sugiurahajime/programming/PythonBayesianMLBook/.venv/lib/python3.9/site-packages (from matplotlib>=3.0->arviz>=0.11.0->pymc3) (9.1.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/sugiurahajime/programming/PythonBayesianMLBook/.venv/lib/python3.9/site-packages (from matplotlib>=3.0->arviz>=0.11.0->pymc3) (1.4.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/sugiurahajime/programming/PythonBayesianMLBook/.venv/lib/python3.9/site-packages (from matplotlib>=3.0->arviz>=0.11.0->pymc3) (4.33.3)
# Requirement already satisfied: cycler>=0.10 in /Users/sugiurahajime/programming/PythonBayesianMLBook/.venv/lib/python3.9/site-packages (from matplotlib>=3.0->arviz>=0.11.0->pymc3) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/sugiurahajime/programming/PythonBayesianMLBook/.venv/lib/python3.9/site-packages (from matplotlib>=3.0->arviz>=0.11.0->pymc3) (3.0.9)
# Requirement already satisfied: cftime in /Users/sugiurahajime/programming/PythonBayesianMLBook/.venv/lib/python3.9/site-packages (from netcdf4->arviz>=0.11.0->pymc3) (1.6.0)
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the '/Users/sugiurahajime/programming/PythonBayesianMLBook/.venv/bin/python3.9 -m pip install --upgrade pip' command.

# %%
import numpy as np
import pandas as pd
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt
import arviz as az

# %%
np.random.seed(123)

# 真のパラメータ
true_w1 = 1.5
true_w2 = 0.8

# サンプルデータ
N = 4
x_data = np.random.uniform(-5, 5, size=N)
y_data = true_w1 * x_data + true_w2  + np.random.normal(0., 1., size=N)

# データプロット
x_plot_data = np.linspace(-5, 5, 100)
y_plot_data = true_w1 * x_plot_data + true_w2 

plt.scatter(x=x_data, y=y_data, marker='o', label='sample data')
plt.plot(x_plot_data, y_plot_data, color='black', label='assumption')
plt.xlabel('x')
plt.ylabel('y')
plt.legend();

# %%
import pymc3 as pm

# %%
# モデルの定義
with pm.Model() as model:

    # 説明変数
    x = pm.Data("x", x_data)

    # 推論パラメータの事前分布
    w1 = pm.Normal('w1', mu=0.0, sigma=10.0)
    w2 = pm.Normal('w2', mu=0.0, sigma=10.0)

    # 尤度関数
    y = pm.Normal('y', mu=w1*x+w2, sigma=1.0, observed=y_data)

# %%
with model:
    # MCMCによる推論
    trace = pm.sample(draws=3000, tune=1000, chains=3, random_seed=1, \
                      return_inferencedata=True)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (3 chains in 2 jobs)
# NUTS: [w2, w1]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='12000' class='' max='12000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [12000/12000 00:34<00:00 Sampling 3 chains, 0 divergences]
#     </div>
# Sampling 3 chains for 1_000 tune and 3_000 draw iterations (3_000 + 9_000 draws total) took 56 seconds.

# %%
az.plot_trace(trace);

# %%
for var_info in az.rhat(trace).values():
  print(var_info.name, var_info.values.round(3), sep=' ')
# Out:
# w1 1.001
# w2 1.001

# %%
az.plot_posterior(trace, hdi_prob=0.9);

# %%
# 検証用データ
x_new = np.linspace(-5, 5, 100)

with model:
    # 検証用データを推論したモデルに入力
    pm.set_data({"x": x_new})

    # 予測分布からサンプリング
    pred = pm.sample_posterior_predictive(trace, samples=1000, random_seed=1) 

y_pred_samples = pred['y']
# Out:
# /Users/sugiurahajime/programming/PythonBayesianMLBook/.venv/lib/python3.9/site-packages/pymc3/sampling.py:1708: UserWarning: samples parameter is smaller than nchains times ndraws, some draws and/or chains may not be represented in the returned posterior predictive sample
#   warnings.warn(
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='1000' class='' max='1000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1000/1000 00:04<00:00]
#     </div>

# %%
# 予測分布からのサンプルをプロット
for i in range(10):
    plt.plot(x_new, y_pred_samples[i,:], lw=1, alpha=0.1, color='g')

plt.scatter(x=x_data, y=y_data, marker='o', label='sample data', zorder=i+2)
plt.xlabel('x');plt.ylabel('y');plt.xlim(-5,5)
plt.legend();

# %%
# %load_ext watermark
# %watermark --iversions
# Out:
# pymc3     : 3.11.5
# seaborn   : 0.11.2
# pandas    : 1.4.2
# sys       : 3.9.12 (main, Mar 26 2022, 15:51:15)
# [Clang 13.1.6 (clang-1316.0.21.2)]
# numpy     : 1.22.1
# matplotlib: 3.5.2
# arviz     : 0.12.1
# scipy     : 1.7.3
